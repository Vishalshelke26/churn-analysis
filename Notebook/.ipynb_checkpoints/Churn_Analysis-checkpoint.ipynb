# %% [markdown]
# #### Import Libraries

# %%
#Basic libraries
import pandas as pd 
import numpy as np

#visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

#pre processing libararies
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split

#classification models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier

#metrics
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,roc_auc_score,roc_curve,auc

#to save the model
import pickle
import json

#warning 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_csv("customer_churn_business_dataset.csv")
df.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# 1            25.140088         Billing         2.0            0
# 2            27.572928         Service         3.0            0
# 3            26.420822       Technical         5.0            1
# 4            26.674579       Technical         4.0            0
#
#    email_open_rate  marketing_click_rate  nps_score survey_response  \
# 0             0.71                  0.40         27       Satisfied
# 1             0.78                  0.33        -19         Neutral
# 2             0.35                  0.49         80         Neutral
# 3             0.83                  0.15        100         Neutral
# 4             0.65                  0.44         21     Unsatisfied
#
#    referral_count churn
# 0               1     0
# 1               2     1
# 2               1     0
# 3               0     0
# 4               1     0
#
# [5 rows x 32 columns]

# %%
print(df.shape)
print(df.columns)
# Out:
# (10000, 32)
# Index(['customer_id', 'gender', 'age', 'country', 'city', 'customer_segment',
#        'tenure_months', 'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             10000 non-null  object
#  1   gender                  10000 non-null  object
#  2   age                     10000 non-null  int64
#  3   country                 10000 non-null  object
#  4   city                    10000 non-null  object
#  5   customer_segment        10000 non-null  object
#  6   tenure_months           10000 non-null  int64
#  7   signup_channel          10000 non-null  object
#  8   contract_type           10000 non-null  object
#  9   monthly_logins          10000 non-null  int64
#  10  weekly_active_days      10000 non-null  int64
#  11  avg_session_time        10000 non-null  float64
#  12  features_used           10000 non-null  int64
#  13  usage_growth_rate       10000 non-null  float64
#  14  last_login_days_ago     10000 non-null  int64
#  15  monthly_fee             10000 non-null  int64
#  16  total_revenue           10000 non-null  int64
#  17  payment_method          10000 non-null  object
#  18  payment_failures        10000 non-null  int64
#  19  discount_applied        10000 non-null  object
#  20  price_increase_last_3m  10000 non-null  object
#  21  support_tickets         10000 non-null  int64
#  22  avg_resolution_time     10000 non-null  float64
#  23  complaint_type          7955 non-null   object
#  24  csat_score              10000 non-null  float64
#  25  escalations             10000 non-null  int64
#  26  email_open_rate         10000 non-null  float64
#  27  marketing_click_rate    10000 non-null  float64
#  28  nps_score               10000 non-null  int64
#  29  survey_response         10000 non-null  object
#  30  referral_count          10000 non-null  int64
#  31  churn                   10000 non-null  int64
# dtypes: float64(6), int64(14), object(12)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                 age  tenure_months  monthly_logins  weekly_active_days  \
# count  10000.000000   10000.000000    10000.000000        10000.000000
# mean      45.906100      30.155700       19.672000            3.479400
# std       16.420416      17.099517        9.838003            2.302283
# min       18.000000       1.000000        0.000000            0.000000
# 25%       32.000000      16.000000       13.000000            1.000000
# 50%       46.000000      30.000000       20.000000            3.000000
# 75%       60.000000      45.000000       26.000000            5.000000
# max       74.000000      59.000000       54.000000            7.000000
#
#        avg_session_time  features_used  usage_growth_rate  \
# count      10000.000000   10000.000000       10000.000000
# mean          15.187890       4.990800           0.019423
# std            6.830774       2.211607           0.149567
# min            1.000000       1.000000          -0.580000
# 25%           10.391645       3.000000          -0.080000
# 50%           15.161659       5.000000           0.020000
# 75%           19.882034       6.000000           0.120000
# max           41.996411      15.000000           0.540000
#
#        last_login_days_ago   monthly_fee  total_revenue  payment_failures  \
# count         10000.000000  10000.000000   10000.000000      10000.000000
# mean              9.505200     34.930000    1057.018000          0.501000
# std               9.799417     23.785115    1020.148233          0.711934
# min               0.000000     10.000000      10.000000          0.000000
# 25%               2.000000     20.000000     340.000000          0.000000
# 50%               6.000000     30.000000     720.000000          0.000000
# 75%              13.000000     50.000000    1440.000000          1.000000
# max              80.000000    100.000000    5900.000000          5.000000
#
#        support_tickets  avg_resolution_time    csat_score   escalations  \
# count     10000.000000         10000.000000  10000.000000  10000.000000
# mean          1.206600            23.953210      3.486700      0.294100
# std           1.104554             9.956999      0.978631      0.543171
# min           0.000000             1.000000      1.000000      0.000000
# 25%           0.000000            17.082041      3.000000      0.000000
# 50%           1.000000            23.950444      4.000000      0.000000
# 75%           2.000000            30.758480      4.000000      1.000000
# max           7.000000            61.821878      5.000000      4.000000
#
#        email_open_rate  marketing_click_rate     nps_score  referral_count  \
# count     10000.000000          10000.000000  10000.000000      10000.0000
# mean          0.499610              0.253575     19.110500          0.9922
# std           0.231601              0.140532     38.936619          0.9939
# min           0.100000              0.010000   -100.000000          0.0000
# 25%           0.300000              0.130000     -7.000000          0.0000
# 50%           0.500000              0.250000     19.000000          1.0000
# 75%           0.700000              0.380000     46.000000          2.0000
# max           0.900000              0.500000    100.000000          7.0000
#
#               churn
# count  10000.000000
# mean       0.102100
# std        0.302795
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# referral_count               0
# churn                        0
# dtype: int64

# %%
df["complaint_type"].value_counts()
# Out:
# complaint_type
# Technical    3498
# Billing      2427
# Service      2030
# Name: count, dtype: int64

# %%
df["complaint_type"].isna().sum()
# Out:
# 2045

# %%
#fill na of the categorical col with mode value
cat_col = df.select_dtypes(include=["object"]).columns
df[cat_col] = df[cat_col].fillna(df[cat_col].mode().iloc[0])

# %%
num_col = df.select_dtypes(include=["int64","float64"]).columns

# %%
df["complaint_type"].head()
# Out:
# 0      Service
# 1      Billing
# 2      Service
# 3    Technical
# 4    Technical
# Name: complaint_type, dtype: object

# %%
df.isnull().sum()
# Out:
# customer_id               0
# gender                    0
# age                       0
# country                   0
# city                      0
# customer_segment          0
# tenure_months             0
# signup_channel            0
# contract_type             0
# monthly_logins            0
# weekly_active_days        0
# avg_session_time          0
# features_used             0
# usage_growth_rate         0
# last_login_days_ago       0
# monthly_fee               0
# total_revenue             0
# payment_method            0
# payment_failures          0
# discount_applied          0
# price_increase_last_3m    0
# support_tickets           0
# avg_resolution_time       0
# complaint_type            0
# csat_score                0
# escalations               0
# email_open_rate           0
# marketing_click_rate      0
# nps_score                 0
# survey_response           0
# referral_count            0
# churn                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(6,4))
sns.countplot(x = "churn",data=df)
plt.title("Churn Distribution")
plt.xlabel("Churn( 0 = No, 1 = Yes)")
plt.ylabel("Cust Count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["churn"].value_counts(normalize=True) *100
# Out:
# churn
# 0    89.79
# 1    10.21
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7,6))
sns.countplot(x= "contract_type",hue="churn",data=df)
plt.title("Contract type vs churn")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x= "customer_segment",data=df,hue="churn")
plt.title("Customer segment vs churn")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["tenure_months"],bins=30,kde=True)
plt.title("Tenure Months Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="churn",y="monthly_logins",data=df)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="monthly_fee", data=df)
plt.title("Monthly Fee vs Churn")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="total_revenue", data=df)
plt.title("Total Revenue vs Churn")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="support_tickets", data=df)
plt.title("Support Tickets vs Churn")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="csat_score", data=df)
plt.title("CSAT Score vs Churn")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="email_open_rate", data=df)
plt.title("Email Open Rate vs Churn")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="churn", y="nps_score", data=df)
plt.title("NPS Score vs Churn")
plt.show()

# %%
plt.figure(figsize=(14,10))
corr = df[num_col].corr()
sns.heatmap(corr, cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap")
plt.show()

# %%
#remove outliers from the data 

def remove_outlier_iqr(data,col):
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3-q1
    lower_tail = q1-1.5 * iqr
    upper_tail = q3+1.5*iqr

    data[col] = data[col].clip(lower_tail,upper_tail)
    return data

# %%
for col in ["monthly_logins", "avg_session_time", "total_revenue"]:
    df= remove_outlier_iqr(df,col)

# %%
#adding new features in the data 
df["avg_revenue_per_month"] = df["total_revenue"] / df["tenure_months"]
df["engagement_score"] = (
    df["monthly_logins"] * 0.4 +
    df["weekly_active_days"] * 0.3 +
    df["email_open_rate"] * 10
)

# %%
#data spliting 
x = df.drop(columns=["customer_id", "churn"])
y = df["churn"]

# %%
print("Total columns:", df.shape[1])
print("X columns:", x.shape[1])
print("y shape:", y.shape)
# Out:
# Total columns: 34
# X columns: 32
# y shape: (10000,)

# %%
categorical_col = x.select_dtypes(include=["object"]).columns
numerical_col = x.select_dtypes(include= ["int64","float64"]).columns
print(f" Categorical col : \n {categorical_col}")
print(f" Numerical col : \n {numerical_col}")
# Out:
#  Categorical col :
#  Index(['gender', 'country', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'payment_method', 'discount_applied',
#        'price_increase_last_3m', 'complaint_type', 'survey_response'],
#       dtype='object')
#  Numerical col :
#  Index(['age', 'tenure_months', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue',
#        'payment_failures', 'support_tickets', 'avg_resolution_time',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'referral_count', 'avg_revenue_per_month',
#        'engagement_score'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

categorical_col = df.select_dtypes(include=["object","category"]).columns
print(f"Categorical col : \n {categorical_col}")


#use leable incoding 

le = LabelEncoder()
for col in categorical_col:
    df[col] = le.fit_transform(df[col].astype(str))


df.head()
# Out:
# Categorical col :
#  Index(['customer_id', 'gender', 'country', 'city', 'customer_segment',
#        'signup_channel', 'contract_type', 'payment_method', 'discount_applied',
#        'price_increase_last_3m', 'complaint_type', 'survey_response'],
#       dtype='object')
#    customer_id  gender  age  country  city  customer_segment  tenure_months  \
# 0            0       1   68        1     3                 2             22
# 1            1       0   57        2     5                 1              9
# 2            2       1   24        3     4                 2             58
# 3            3       1   49        0     2                 1             19
# 4            4       1   65        1     1                 1             52
#
#    signup_channel  contract_type  monthly_logins  ...  csat_score  \
# 0               2              0            26.0  ...         4.0
# 1               0              0             7.0  ...         2.0
# 2               2              2            19.0  ...         3.0
# 3               0              2            34.0  ...         5.0
# 4               2              0            20.0  ...         4.0
#
#    escalations  email_open_rate  marketing_click_rate  nps_score  \
# 0            0             0.71                  0.40         27
# 1            0             0.78                  0.33        -19
# 2            0             0.35                  0.49         80
# 3            1             0.83                  0.15        100
# 4            0             0.65                  0.44         21
#
#    survey_response  referral_count  churn  avg_revenue_per_month  \
# 0                1               1      0                   30.0
# 1                0               2      1                   30.0
# 2                0               1      0                   20.0
# 3                0               0      0                   30.0
# 4                2               1      0                   50.0
#
#    engagement_score
# 0              19.6
# 1              12.1
# 2              12.6
# 3              24.0
# 4              16.3
#
# [5 rows x 34 columns]

# %%
# Separate features and target
X = df.drop('churn', axis=1)
y = df['churn']

# %%
#minmax scaling

scalar = MinMaxScaler()
X_scaled = pd.DataFrame(scalar.fit_transform(X),columns=X.columns)
X_scaled
# Out:
#       customer_id  gender       age   country      city  customer_segment  \
# 0          0.0000     1.0  0.892857  0.166667  0.500000               1.0
# 1          0.0001     0.0  0.696429  0.333333  0.833333               0.5
# 2          0.0002     1.0  0.107143  0.500000  0.666667               1.0
# 3          0.0003     1.0  0.553571  0.000000  0.333333               0.5
# 4          0.0004     1.0  0.839286  0.166667  0.166667               0.5
# ...           ...     ...       ...       ...       ...               ...
# 9995       0.9996     0.0  0.875000  0.500000  0.833333               1.0
# 9996       0.9997     1.0  0.142857  1.000000  1.000000               0.5
# 9997       0.9998     0.0  0.000000  0.333333  0.833333               0.5
# 9998       0.9999     0.0  0.214286  1.000000  0.166667               0.5
# 9999       1.0000     1.0  0.875000  0.833333  0.000000               1.0
#
#       tenure_months  signup_channel  contract_type  monthly_logins  ...  \
# 0          0.362069             1.0            0.0        0.571429  ...
# 1          0.137931             0.0            0.0        0.153846  ...
# 2          0.982759             1.0            1.0        0.417582  ...
# 3          0.310345             0.0            1.0        0.747253  ...
# 4          0.879310             1.0            0.0        0.439560  ...
# ...             ...             ...            ...             ...  ...
# 9995       0.620690             1.0            1.0        0.329670  ...
# 9996       0.706897             0.0            1.0        0.285714  ...
# 9997       0.655172             0.0            1.0        0.329670  ...
# 9998       0.879310             1.0            0.0        0.307692  ...
# 9999       0.103448             0.0            0.0        0.329670  ...
#
#       complaint_type  csat_score  escalations  email_open_rate  \
# 0                0.5        0.75         0.00           0.7625
# 1                0.0        0.25         0.00           0.8500
# 2                0.5        0.50         0.00           0.3125
# 3                1.0        1.00         0.25           0.9125
# 4                1.0        0.75         0.00           0.6875
# ...              ...         ...          ...              ...
# 9995             0.5        0.75         0.25           0.3250
# 9996             1.0        0.75         0.00           0.4750
# 9997             1.0        0.00         0.00           0.0125
# 9998             1.0        0.25         0.00           0.1875
# 9999             1.0        0.75         0.25           0.3750
#
#       marketing_click_rate  nps_score  survey_response  referral_count  \
# 0                 0.795918      0.635              0.5        0.142857
# 1                 0.653061      0.405              0.0        0.285714
# 2                 0.979592      0.900              0.0        0.142857
# 3                 0.285714      1.000              0.0        0.000000
# 4                 0.877551      0.605              1.0        0.142857
# ...                    ...        ...              ...             ...
# 9995              0.551020      0.600              0.5        0.285714
# 9996              0.102041      0.640              1.0        0.285714
# 9997              0.122449      0.350              0.5        0.142857
# 9998              0.612245      0.790              0.0        0.142857
# 9999              0.591837      0.505              0.5        0.142857
#
#       avg_revenue_per_month  engagement_score
# 0                  0.222222          0.665455
# 1                  0.222222          0.392727
# 2                  0.111111          0.410909
# 3                  0.222222          0.825455
# 4                  0.444444          0.545455
# ...                     ...               ...
# 9995               0.111111          0.323636
# 9996               0.444444          0.338182
# 9997               0.111111          0.276364
# 9998               0.222222          0.247273
# 9999               0.222222          0.327273
#
# [10000 rows x 33 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (8000, 33)
# Test shape: (2000, 33)

# %%
Models = {
    "LogisticRegression" : LogisticRegression(),
    "KNN" : KNeighborsClassifier(),
    "DecisionTree" : DecisionTreeClassifier(),
    "Adaboost" : AdaBoostClassifier(),
    "RandomForeset" : RandomForestClassifier()
}

# %%
Result = []

# %%
for name, Model in Models.items():
    Model.fit(X_train,y_train)

    y_pred = Model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1] if hasattr(model, "predict_proba") else None

    acc = accuracy_score(y_test,y_pred)
    cm = confusion_matrix(y_test,y_pred)
    clf_report = confusion_matrix(y_test,y_pred)
    train_acc = Model.score(X_train,y_train)


        # ROC-AUC
    if y_proba is not None:
        roc_auc = roc_auc_score(y_test, y_proba)
    else:
        roc_auc = "N/A"
    
    Result.append({
        "Model": name,
        "Accuracy": acc,
        "Confusion_Matrix": cm,
        "Classification_Report": clf_report,
        "ROC_AUC": roc_auc,
        "Training Accuracy":train_acc,
    })


# Convert to DataFrame
results_df = pd.DataFrame(Result)
results_df[['Model', 'Accuracy', 'ROC_AUC','Training Accuracy']]
# Out:
#                 Model  Accuracy   ROC_AUC  Training Accuracy
# 0  LogisticRegression    0.8955  0.724538                NaN
# 1                 KNN    0.8900  0.724538                NaN
# 2        DecisionTree    0.8295  0.724538                NaN
# 3            Adaboost    0.8970  0.724538                NaN
# 4       RandomForeset    0.8985  0.724538                NaN
# 5  LogisticRegression    0.8955  0.724538           0.896750
# 6                 KNN    0.8900  0.724538           0.900500
# 7        DecisionTree    0.8260  0.724538           1.000000
# 8            Adaboost    0.8970  0.724538           0.896375
# 9       RandomForeset    0.8970  0.724538           0.999625

# %%
# Confusion Matrix
Model = Models['RandomForeset']
y_pred = Model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
y_proba = model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Random Forest ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %%
importances = Model.feature_importances_
feature_importance = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title("Random Forest Feature Importance")
plt.show()

# %%
importances = Model.feature_importances_
importances
# Out:
# array([0.04994174, 0.00691702, 0.04192257, 0.02368175, 0.02419648,
#        0.01128034, 0.06857467, 0.01167696, 0.01232327, 0.05654424,
#        0.02623903, 0.04943401, 0.02755508, 0.04424199, 0.04423126,
#        0.01627071, 0.05260719, 0.01082844, 0.03317137, 0.00764042,
#        0.00576955, 0.01732591, 0.04895404, 0.01100287, 0.05863072,
#        0.00928837, 0.04346862, 0.04070086, 0.04443394, 0.0124029 ,
#        0.01456306, 0.02061444, 0.0535662 ])

# %%
feature_name = Model.feature_names_in_

# %%
dic1 = dict(zip(feature_name,importances))
dic1
# Out:
# {'customer_id': 0.049941743702283235,
#  'gender': 0.006917024183815404,
#  'age': 0.041922571463816366,
#  'country': 0.023681746219634286,
#  'city': 0.02419647581441443,
#  'customer_segment': 0.011280343500249706,
#  'tenure_months': 0.06857466877345096,
#  'signup_channel': 0.011676957175336082,
#  'contract_type': 0.012323267434205858,
#  'monthly_logins': 0.05654423619604923,
#  'weekly_active_days': 0.026239031300590437,
#  'avg_session_time': 0.049434005749974856,
#  'features_used': 0.027555076828517603,
#  'usage_growth_rate': 0.04424199094469243,
#  'last_login_days_ago': 0.04423126202098508,
#  'monthly_fee': 0.016270711267822643,
#  'total_revenue': 0.05260718580775117,
#  'payment_method': 0.010828438053700911,
#  'payment_failures': 0.033171373800745856,
#  'discount_applied': 0.007640422981403652,
#  'price_increase_last_3m': 0.005769554039221986,
#  'support_tickets': 0.017325912277920134,
#  'avg_resolution_time': 0.04895403611873867,
#  'complaint_type': 0.011002868276516729,
#  'csat_score': 0.058630716704621805,
#  'escalations': 0.009288366101961902,
#  'email_open_rate': 0.04346861856260487,
#  'marketing_click_rate': 0.040700858563373715,
#  'nps_score': 0.04443393562348378,
#  'survey_response': 0.01240290481380825,
#  'referral_count': 0.01456305583817888,
#  'avg_revenue_per_month': 0.020614439415506555,
#  'engagement_score': 0.05356620044462254}

# %%
imp_features = dict()
for fe,imp in enumerate(dic1):
    if dic1[imp] >= 0.03:
        print(f"{imp} with the importance : {dic1[imp]}")
        imp_features.update({imp:dic1[imp]})
# Out:
# customer_id with the importance : 0.049941743702283235
# age with the importance : 0.041922571463816366
# tenure_months with the importance : 0.06857466877345096
# monthly_logins with the importance : 0.05654423619604923
# avg_session_time with the importance : 0.049434005749974856
# usage_growth_rate with the importance : 0.04424199094469243
# last_login_days_ago with the importance : 0.04423126202098508
# total_revenue with the importance : 0.05260718580775117
# payment_failures with the importance : 0.033171373800745856
# avg_resolution_time with the importance : 0.04895403611873867
# csat_score with the importance : 0.058630716704621805
# email_open_rate with the importance : 0.04346861856260487
# marketing_click_rate with the importance : 0.040700858563373715
# nps_score with the importance : 0.04443393562348378
# engagement_score with the importance : 0.05356620044462254

# %%
imp_features
# Out:
# {'customer_id': 0.049941743702283235,
#  'age': 0.041922571463816366,
#  'tenure_months': 0.06857466877345096,
#  'monthly_logins': 0.05654423619604923,
#  'avg_session_time': 0.049434005749974856,
#  'usage_growth_rate': 0.04424199094469243,
#  'last_login_days_ago': 0.04423126202098508,
#  'total_revenue': 0.05260718580775117,
#  'payment_failures': 0.033171373800745856,
#  'avg_resolution_time': 0.04895403611873867,
#  'csat_score': 0.058630716704621805,
#  'email_open_rate': 0.04346861856260487,
#  'marketing_click_rate': 0.040700858563373715,
#  'nps_score': 0.04443393562348378,
#  'engagement_score': 0.05356620044462254}

# %%
sorted_imp = dict(
    sorted(imp_features.items(),key=lambda x :x[1],reverse=True)
)

# %%
# Plot
plt.figure(figsize=(10,6))
sns.barplot(x = list(sorted_imp.values()) ,y=list(sorted_imp.keys()),data=sorted_imp)
plt.xticks(rotation=90)
plt.show()

# %%
X_train.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'country', 'city', 'customer_segment',
#        'tenure_months', 'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'avg_revenue_per_month',
#        'engagement_score'],
#       dtype='object')

# %%
sorted_imp.keys()
# Out:
# dict_keys(['tenure_months', 'csat_score', 'monthly_logins', 'engagement_score', 'total_revenue', 'customer_id', 'avg_session_time', 'avg_resolution_time', 'nps_score', 'usage_growth_rate', 'last_login_days_ago', 'email_open_rate', 'age', 'marketing_click_rate', 'payment_failures'])

# %%
X_new = X_scaled
X_new.head()
# Out:
#    customer_id  gender       age   country      city  customer_segment  \
# 0       0.0000     1.0  0.892857  0.166667  0.500000               1.0
# 1       0.0001     0.0  0.696429  0.333333  0.833333               0.5
# 2       0.0002     1.0  0.107143  0.500000  0.666667               1.0
# 3       0.0003     1.0  0.553571  0.000000  0.333333               0.5
# 4       0.0004     1.0  0.839286  0.166667  0.166667               0.5
#
#    tenure_months  signup_channel  contract_type  monthly_logins  ...  \
# 0       0.362069             1.0            0.0        0.571429  ...
# 1       0.137931             0.0            0.0        0.153846  ...
# 2       0.982759             1.0            1.0        0.417582  ...
# 3       0.310345             0.0            1.0        0.747253  ...
# 4       0.879310             1.0            0.0        0.439560  ...
#
#    complaint_type  csat_score  escalations  email_open_rate  \
# 0             0.5        0.75         0.00           0.7625
# 1             0.0        0.25         0.00           0.8500
# 2             0.5        0.50         0.00           0.3125
# 3             1.0        1.00         0.25           0.9125
# 4             1.0        0.75         0.00           0.6875
#
#    marketing_click_rate  nps_score  survey_response  referral_count  \
# 0              0.795918      0.635              0.5        0.142857
# 1              0.653061      0.405              0.0        0.285714
# 2              0.979592      0.900              0.0        0.142857
# 3              0.285714      1.000              0.0        0.000000
# 4              0.877551      0.605              1.0        0.142857
#
#    avg_revenue_per_month  engagement_score
# 0               0.222222          0.665455
# 1               0.222222          0.392727
# 2               0.111111          0.410909
# 3               0.222222          0.825455
# 4               0.444444          0.545455
#
# [5 rows x 33 columns]

# %%
for i in X_scaled.columns:
   if i not in sorted_imp.keys():
      X_new = X_new.drop(i,axis=1)

# %%
X_new.shape
# Out:
# (10000, 15)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X_new, y, test_size=0.2, random_state=42, stratify=y
)

print("Train shape:", X_train1.shape)
print("Test shape:", X_test1.shape)
# Out:
# Train shape: (8000, 15)
# Test shape: (2000, 15)

# %%
rf = RandomForestClassifier()
rf.fit(X_train1,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_new = rf.predict(X_test1)
acc1 = accuracy_score(y_test,y_pred_new)
cm1 = confusion_matrix(y_test,y_pred_new)
clf_report1 = confusion_matrix(y_test,y_pred_new)

# %%
print(acc1)
# Out:
# 0.8995

# %%
rf.score(X_train1,y_train1)
# Out:
# 1.0

# %%
knn = KNeighborsClassifier()
knn.fit(X_train1,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_new = knn.predict(X_test1)
acc1 = accuracy_score(y_test,y_pred_new)
cm1 = confusion_matrix(y_test,y_pred_new)
clf_report1 = confusion_matrix(y_test,y_pred_new)

# %%
print(acc1)
# Out:
# 0.8925

# %%
knn.score(X_train1,y_train)
# Out:
# 0.90725

# %%
# Confusion Matrix

y_pred_new1 = rf.predict(X_test1)
cm2 = confusion_matrix(y_test, y_pred_new1)

plt.figure(figsize=(6,5))
sns.heatmap(cm2, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
y_proba_new = rf.predict_proba(X_test1)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba_new)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Random Forest ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %%
# Confusion Matrix

y_pred_new1 = knn.predict(X_test1)
cm2 = confusion_matrix(y_test, y_pred_new1)

plt.figure(figsize=(6,5))
sns.heatmap(cm2, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
y_proba_new = knn.predict_proba(X_test1)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba_new)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("KNN ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %%
lg = LogisticRegression()
lg.fit(X_train1,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_new = knn.predict(X_test1)
acc1 = accuracy_score(y_test,y_pred_new)
cm1 = confusion_matrix(y_test,y_pred_new)
clf_report1 = confusion_matrix(y_test,y_pred_new)

# %%
print(acc1)
# Out:
# 0.8925

# %%
lg.score(X_train1,y_train)
# Out:
# 0.897125

# %%
# Confusion Matrix

y_pred_new1 = lg.predict(X_test1)
cm2 = confusion_matrix(y_test, y_pred_new1)

plt.figure(figsize=(6,5))
sns.heatmap(cm2, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
y_proba_new = lg.predict_proba(X_test1)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba_new)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("logisticregg ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Testing on User Data

# %%
test_df = X_train[100:101]
test_df
# Out:
#       customer_id  gender       age  country  city  customer_segment  \
# 6968      0.69687     0.0  0.857143      0.0   1.0               0.0
#
#       tenure_months  signup_channel  contract_type  monthly_logins  ...  \
# 6968       0.241379             0.5            0.0             0.0  ...
#
#       complaint_type  csat_score  escalations  email_open_rate  \
# 6968             0.0         0.5          0.0           0.4625
#
#       marketing_click_rate  nps_score  survey_response  referral_count  \
# 6968              0.571429       0.19              0.5        0.285714
#
#       avg_revenue_per_month  engagement_score
# 6968                    1.0          0.156364
#
# [1 rows x 33 columns]

# %%
Model.predict(X_train[4:5])
# Out:
# array([1], dtype=int64)

# %%
y_train[4:5]
# Out:
# 8440    1
# Name: churn, dtype: int64

# %%
y_train.head()
# Out:
# 3529    0
# 8625    0
# 9234    0
# 5779    0
# 8440    1
# Name: churn, dtype: int64

# %%
X_train.shape
# Out:
# (8000, 33)

# %%
test_arr = np.zeros((1,33))
test_arr.shape
# Out:
# (1, 33)

# %%
Model.predict(test_arr)
# Out:
# array([0], dtype=int64)

# %%
with open("churn_model.pkl","wb") as f:
    pickle.dump(lg,f)
